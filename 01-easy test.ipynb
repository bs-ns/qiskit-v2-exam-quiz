# %% [markdown]
# # Qiskit v2 Certification Practice Test - Easy questions

# %% [markdown]
# ## Question 1
#
# Given:
#
# ```python
# from qiskit.quantum_info import Pauli
#
# p = Pauli("YZ")
# ```
#
# What is the correct interpretation of this Pauli operator?
#
# A. $Z$ acts on qubit 0 and $Y$ acts on qubit 1
#
# B. $Y$ acts on qubit 0 and $Z$ acts on qubit 1
#
# C. Apply $Y$ then $Z$ sequentially to the same qubit
#
# D. Controlled-$Z$ followed by $Y$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# Qiskit uses little-endian ordering.
#
#
# </details>
#
# ---

# %% [markdown]
# ## Question 2
#
# A qubit is initialized in state $|0\rangle$.
#
# The following gate is applied:
#
# ```python
# qc.ry(np.pi/2, 0)
# ```
#
# What is the probability of measuring $1$?
#
# A. $0$
#
# B. $\frac{1}{4}$
#
# C. $\frac{1}{2}$
#
# D. $1$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# this corresponds to H
#
# </details>
#
# ---

# %% [markdown]
# ## Question 3
#
# Consider:
#
# ```python
# qc.h(0)
# qc.cx(0,1)
# ```
#
# Which state is produced?
#
# A. $\frac{|00\rangle + |11\rangle}{\sqrt{2}}$
#
# B. $\frac{|00\rangle + |01\rangle}{\sqrt{2}}$
#
# C. $\frac{|10\rangle + |11\rangle}{\sqrt{2}}$
#
# D. $|00\rangle$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
#
#
# </details>
#
# ---

# %% [markdown]
# ## Question 4
#
# What is the purpose of a `ClassicalRegister`?
#
# A. Store amplitudes
#
# B. Store measurement outcomes
#
# C. Store ancilla qubits
#
# D. Optimize circuits
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 5
#
# Consider:
#
# ```python
# theta = Parameter("θ")
#
# qc.rx(theta,0)
# ```
#
# Why are parameters useful?
#
# A. They automatically optimize circuits
#
# B. They perform error mitigation
#
# C. They export OpenQASM
#
# D. They allow reuse of a circuit with different values
#
# <details>
# <summary>Answer</summary>
#
# **Answer: D**
#
#
# </details>
#
# ---

# %% [markdown]
# ## Question 6
#
# Starting from $|0\rangle$:
#
# ```python
# qc.x(0)
# qc.h(0)
# ```
#
# What is the final state?
#
# A. $\frac{|0\rangle + |1\rangle}{\sqrt{2}}$
#
# B. $\frac{|0\rangle - |1\rangle}{\sqrt{2}}$
#
# C. $|1\rangle$
#
# D. $|0\rangle$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 7
#
# Which function visualizes a quantum state on Bloch spheres?
#
# A. `plot_histogram`
#
# B. `plot_gate_map`
#
# C. `plot_bloch_multivector`
#
# D. `circuit.draw()`
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 8
#
# A SamplerV2 job returns: $P(00)=0.5$ and $P(11)=0.5$
#
# If 1000 shots are used, how many counts of `11` are expected?
#
# A. 0
#
# B. 250
#
# C. 500
#
# D. 1000
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 9
#
# What is the primary difference between SamplerV2 and EstimatorV2?
#
# A. Sampler returns measurement distributions while Estimator returns expectation values.
#
# B. Sampler only works on simulators.
#
# C. Estimator returns bitstrings.
#
# D. They are identical.
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 10
#
# Which is a valid EstimatorV2 PUB?
#
# A. (circuit, shots, backend)
#
# B. (circuit, observable, parameter_values, precision)
#
# C. (observable, circuit, optimization_level)
#
# D. (circuit, observable, noise_model)
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 11
#
# What is the primary purpose of transpilation?
#
# A. Execute a circuit on a backend
#
# B. Convert counts into probabilities
#
# C. Apply error mitigation
#
# D. Convert a circuit into a backend-compatible optimized circuit
#
# <details>
# <summary>Answer</summary>
#
# **Answer: D**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 12
#
# What is generally true about:
#
# ```python
# optimization_level=3
# ```
#
# A. No optimization is performed
#
# B. It performs the most aggressive optimization
#
# C. It guarantees the shortest possible circuit
#
# D. It only works on simulators
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# Level 3 applies the most aggressive optimization strategies available.
#
# </details>
#
# ---

# %% [markdown]
# ## Question 13
#
# Consider:
#
# ```python
# with qc.if_test((0, 1)):
#     qc.x(1)
# ```
#
# What does the condition mean?
#
# A. Apply X if classical bit 0 equals 1
#
# B. Apply X if qubit 1 equals 1
#
# C. Apply X on qubit 0
#
# D. Apply X if the circuit depth equals 1
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 14
#
# Which execution mode is best suited for iterative variational algorithms?
#
# A. Job mode
#
# B. Session mode
#
# C. Batch mode
#
# D. OpenQASM mode
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# A Session keeps related jobs together and reduces queueing delays between iterations.
#
# </details>
#
# ---

# %% [markdown]
# ## Question 15
#
# Which statement about Batch mode is correct?
#
# A. It groups a large collection of jobs for efficient execution
#
# B. It is required by EstimatorV2
#
# C. It enables classical control flow
#
# D. It only works on simulators
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 16
#
# Which Sampler option inserts idle-gate sequences to reduce decoherence?
#
# A. Twirling
#
# B. Resilience
#
# C. Dynamical decoupling
#
# D. Precision
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# Dynamical decoupling inserts pulses during idle periods to reduce noise.
#
# </details>
#
# ---

# %% [markdown]
# ## Question 17
#
# Which Estimator resilience technique attempts to estimate the zero-noise value?
#
# A. Dynamical decoupling
#
# B. Zero Noise Extrapolation (ZNE)
#
# C. Circuit cutting
#
# D. Statevector simulation
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 18
#
# Suppose the precision changes from 0.015 to 0.035
#
# What generally happens?
#
# A. More shots are required
#
# B. The same number of shots are required
#
# C. Fewer shots are required
#
# D. The job fails
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 19
#
# Consider the Bell-state circuit:
#
# ```python
# qc.h(0)
# qc.cx(0,1)
# ```
#
# Which measurement outcomes are observed ideally?
#
# A. `01` and `10`
#
# B. `00` and `11`
#
# C. All four outcomes equally
#
# D. Only `00`
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 20
#
# Which function is commonly used to visualize measurement frequencies?
#
# A. `plot_bloch_multivector`
#
# B. `plot_state_qsphere`
#
# C. `plot_histogram`
#
# D. `plot_gate_map`
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# </details>

# %% [markdown]
# ## Question 21
#
# Which OpenQASM 3 type is a valid classical type?
#
# A. `complex`
#
# B. `qudit`
#
# C. `quantum`
#
# D. `unitary`
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# OpenQASM 3 supports classical types such as `int`, `float`, `bool`, and `complex`.
#
# </details>
#
# ---

# %% [markdown]
# ## Question 22
#
# Which statement about the Pauli-$X$ gate is correct?
#
# A. It leaves both basis states unchanged
#
# B. It swaps $|0\rangle$ and $|1\rangle$
#
# C. It adds a phase to $|1\rangle$
#
# D. It creates superposition
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 23
#
# What is the matrix dimension of:
#
# ```python
# Pauli("ZZ")
# ```
#
# A. $2\times2$
#
# B. $2\times4$
#
# C. $4\times4$
#
# D. $8\times8$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 24
#
# Starting from $|0\rangle$:
#
# ```python
# qc.h(0)
# qc.z(0)
# ```
#
# What is the final state?
#
# A. $\frac{|0\rangle+|1\rangle}{\sqrt{2}}$
#
# B. $\frac{|0\rangle-|1\rangle}{\sqrt{2}}$
#
# C. $|1\rangle$
#
# D. $-|0\rangle$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# After the Hadamard:
#
# $|+\rangle = \frac{|0\rangle+|1\rangle}{\sqrt{2}}$
#
# Applying $Z$ gives:
#
# $|-\rangle = \frac{|0\rangle-|1\rangle}{\sqrt{2}}$
#
# </details>
#
# ---

# %% [markdown]
# ## Question 25
#
# What is returned by:
#
# ```python
# job = sampler.run(...)
# ```
#
# A. A `QuantumCircuit`
#
# B. A Job object
#
# C. A histogram
#
# D. A backend
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# The call returns a Job object that can later be queried for status and results.
#
# </details>
#
# ---

# %% [markdown]
# ## Question 26
#
# Which statement about the Pauli-$Z$ gate is correct?
#
# A. It swaps $|0\rangle$ and $|1\rangle$
#
# B. It transforms $|0\rangle$ into $-|0\rangle$
#
# C. It leaves $|0\rangle$ unchanged and adds a phase to $|1\rangle$
#
# D. It creates superposition
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 27
#
# Starting from $|0\rangle$:
#
# ```python
# qc.ry(theta,0)
# ```
#
# with
#
# $theta = 0$
#
# What is the final state?
#
# A. $|0\rangle$
#
# B. $|1\rangle$
#
# C. $\frac{|0\rangle+|1\rangle}{\sqrt{2}}$
#
# D. $\frac{|0\rangle-|1\rangle}{\sqrt{2}}$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# $R_y(0)$ is the identity operation.
#
# </details>
#
# ---

# %% [markdown]
# ## Question 28
#
# Which statement best describes a Session?
#
# A. A visualization tool
#
# B. A mechanism that groups related primitive calls
#
# C. An OpenQASM exporter
#
# D. A transpiler pass
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 29
#
# Which function exports a circuit to OpenQASM 3?
#
# A.
#
# ```python
# qc.to_openqasm3()
# ```
#
# B.
#
# ```python
# qiskit.qasm3.export()
# ```
#
# C.
#
# ```python
# export_to_qasm3()
# ```
#
# D.
#
# ```python
# qiskit.qasm3.dump()
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: D**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 30
#
# Starting from $|00\rangle$:
#
# ```python
# qc.x(1)
# qc.cx(1,0)
# ```
#
# What is the final state?
#
# A. $|00\rangle$
#
# B. $|01\rangle$
#
# C. $|11\rangle$
#
# D. $\frac{|00\rangle+|11\rangle}{\sqrt{2}}$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 31
#
# What best describes Pauli twirling?
#
# A. A technique that converts coherent errors into stochastic Pauli errors
#
# B. A Bloch sphere visualization method
#
# C. A transpilation optimization pass
#
# D. A circuit export format
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# Pauli twirling randomizes certain coherent errors, making them behave more like stochastic noise that is easier to model and mitigate.
#
# </details>
#
# ---

# %% [markdown]
# ## Question 32
#
# Which primitive computes expectation values?
#
# A. SamplerV2
#
# B. Transpiler
#
# C. EstimatorV2
#
# D. Session
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 33
#
# Consider:
#
# ```python
# qc.h(0)
# qc.measure_all()
# ```
#
# What measurement distribution is expected ideally?
#
# A. `{'0': 1.0}`
#
# B. `{'1': 1.0}`
#
# C. `{'0': 0.5, '1': 0.5}`
#
# D. `{'00': 0.5, '11': 0.5}`
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 34
#
# Which object is commonly used to represent observables in Qiskit?
#
# A. `ClassicalRegister`
#
# B. `QuantumRegister`
#
# C. `SparsePauliOp`
#
# D. `PassManager`
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 35
#
# Which job status indicates successful completion?
#
# A. `RUNNING`
#
# B. `QUEUED`
#
# C. `DONE`
#
# D. `INITIALIZING`
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# A completed job has status:
#
# ```python
# DONE
# ```
#
# </details>
#
# ---

# %% [markdown]
# ## Question 36
#
# Starting from $|0\rangle$:
#
# ```python
# qc.h(0)
# qc.h(0)
# ```
#
# What is the final state?
#
# A. $|0\rangle$
#
# B. $|1\rangle$
#
# C. $\frac{|0\rangle+|1\rangle}{\sqrt{2}}$
#
# D. $\frac{|0\rangle-|1\rangle}{\sqrt{2}}$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
#
# </details>
#
# ---

# %% [markdown]
# ## Question 37
#
# Consider:
#
# ```python
# Statevector.from_label("+")
# ```
#
# Which state does this represent?
#
# A. $|0\rangle$
#
# B. $|1\rangle$
#
# C. $\frac{|0\rangle+|1\rangle}{\sqrt{2}}$
#
# D. $\frac{|0\rangle-|1\rangle}{\sqrt{2}}$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 38
#
# What does broadcasting allow in Runtime primitives?
#
# A. Automatic combinations of circuits, observables, and parameter sets
#
# B. Sending jobs to every backend simultaneously
#
# C. Duplicating qubits
#
# D. A Sampler-only feature
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# Broadcasting allows efficient evaluation of many combinations of:
#
# - circuits
# - observables
# - parameter values
#
# within a single primitive call.
#
# </details>
#
# ---

# %% [markdown]
# ## Question 39
#
# What best describes the output of SamplerV2?
#
# A. Expectation values
#
# B. Measurement distributions
#
# C. Transpiled circuits
#
# D. OpenQASM source code
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# </details>
