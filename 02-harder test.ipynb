# %% [markdown]
# # Qiskit v2 Certification Practice Test  - Difficult questions

# %% [markdown]
# ## Question 1
#
# Consider:
#
# ```python
# qc.h(0)
# qc.cx(0,1)
# ```
#
# The observable is:
#
# ```python
# SparsePauliOp(["ZZ"])
# ```
#
# What is the value of $\langle ZZ \rangle$?
#
# A. $-1$
#
# B. $0$
#
# C. $1$
#
# D. Depends on the number of shots
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
#
# </details>
#
# ---

# %% [markdown]
# ## Question 2
#
# Consider:
#
# ```python
# qc.h(0)
# qc.cx(0,1)
# qc.z(0)
# ```
#
# Which Bell state is produced?
#
# A. $|\Phi^+\rangle$
#
# B. $|\Phi^-\rangle$
#
# C. $|\Psi^+\rangle$
#
# D. $|\Psi^-\rangle$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
# </details>
#
# ---

# %% [markdown]
# ## Question 3
#
# For the Bell state
#
# $|\Phi^+\rangle=\frac{|00\rangle+|11\rangle}{\sqrt{2}}$
#
# what is $\langle XX \rangle$?
#
# A. $-1$
#
# B. $0$
#
# C. $1$
#
# D. $2$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 4
#
# For
#
# $|\Phi^+\rangle=\frac{|00\rangle+|11\rangle}{\sqrt{2}}$
#
# what is $\langle ZI \rangle$?
#
# A. $-1$
#
# B. $0$
#
# C. $1$
#
# D. $2$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 5
#
# Consider:
#
# ```python
# theta = Parameter("θ")
#
# pub = (
#     circuit,
#     observable,
#     [[0],[1],[2]]
# )
# ```
#
# The circuit contains exactly one parameter.
#
# How many expectation values are computed?
#
# A. 1
#
# B. 2
#
# C. 3
#
# D. 6
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 6
#
# Consider:
#
# ```python
# qc.ry(np.pi/2,0)
# ```
#
# What is the value of $\langle X \rangle$?
#
# A. $-1$
#
# B. $0$
#
# C. $\frac{\sqrt{2}}{2}$
#
# D. $1$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: D**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 7
#
# For
#
# $|-\rangle=\frac{|0\rangle-|1\rangle}{\sqrt{2}}$
#
# what is $\langle X\rangle$?
#
# A. $-1$
#
# B. $0$
#
# C. $1$
#
# D. Depends on the number of shots
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 8
#
# Consider:
#
# ```python
# from qiskit.quantum_info import Pauli
#
# Pauli("XYZ")
# ```
#
# Which qubit is acted upon by $Z$?
#
# A. q0
#
# B. q1
#
# C. q2
#
# D. all qubits
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 9
#
# Consider:
#
# ```python
# pub = (
#     circuit,
#     [obs1, obs2],
#     [[0],[np.pi/2],[np.pi]]
# )
# ```
#
# How many expectation values are produced?
#
# A. 2
#
# B. 3
#
# C. 5
#
# D. 6
#
# <details>
# <summary>Answer</summary>
#
# **Answer: D**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 10
#
# For
#
# $|\Psi^-\rangle=\frac{|01\rangle-|10\rangle}{\sqrt{2}}$
#
# what is
#
# $\langle XX+YY+ZZ\rangle$ ?
#
# A. $-3$
#
# B. $-1$
#
# C. $1$
#
# D. $3$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# For $|\Psi^-\rangle$:
#
# $\langle XX\rangle=-1$
#
# $\langle YY\rangle=-1$
#
# $\langle ZZ\rangle=-1$
#
# Therefore:
#
# $-1-1-1=-3$
#
# </details>
#
# ---

# %% [markdown]
# ## Question 11
#
# Consider the Bell state:
#
# $|\Phi^+\rangle=\frac{|00\rangle+|11\rangle}{\sqrt{2}}$
#
# What is the value of:
#
# $\langle XX + YY \rangle$
#
# A. $-2$
#
# B. $-1$
#
# C. $0$
#
# D. $2$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# For $|\Phi^+\rangle$:
#
# $\langle XX\rangle=1$
#
# $\langle YY\rangle=-1$
#
# Therefore:
#
# $1+(-1)=0$
#
# </details>
#
# ---

# %% [markdown]
# ## Question 12
#
# Consider:
#
# ```python
# pub = (
#     circuit,
#     [[obs1], [obs2], [obs3]],
#     [[0], [1], [2], [3]]
# )
# ```
#
# The circuit contains exactly one parameter.
#
# What is the shape of the expectation-value grid?
#
# A. 3 × 4
#
# B. 4 × 3
#
# C. 7
#
# D. 12 × 12
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# There are:
#
# - 3 observables
# - 4 parameter sets
#
# Estimator evaluates every combination.
#
# Grid shape: 3 × 4
#
# Total values: 12
#
# </details>
#
# ---

# %% [markdown]
# ## Question 13
#
# Starting from $|00\rangle$:
#
# ```python
# qc.x(0)
# qc.h(0)
# qc.cx(0,1)
# qc.z(1)
# ```
#
# Which Bell state is produced?
#
# A. $|\Phi^+\rangle$
#
# B. $|\Phi^-\rangle$
#
# C. $|\Psi^+\rangle$
#
# D. $|\Psi^-\rangle$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 14
#
# For
#
# $|\Psi^+\rangle=\frac{|01\rangle+|10\rangle}{\sqrt{2}}$
#
# what is:
#
# $\langle XX - YY + ZZ\rangle$
#
# A. $-1$
#
# B. $0$
#
# C. $1$
#
# D. $3$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# For $|\Psi^+\rangle$:
#
# $\langle XX\rangle=1$
#
# $\langle YY\rangle=1$
#
# $\langle ZZ\rangle=-1$
#
# Therefore:
#
# $1-1-1=-1$
#
# </details>
#
# ---

# %% [markdown]
# ## Question 15
#
# A qubit is prepared as:
#
# $R_y(\pi/4)|0\rangle$
#
# Estimator evaluates:
#
# $\langle X+Z\rangle$
#
# What is returned?
#
# A. $0$
#
# B. $\sqrt{2}$
#
# C. $1$
#
# D. $\frac{\sqrt{2}}{2}$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# For $R_y(\theta)|0\rangle$:
#
# $\langle X\rangle=\sin(\theta)$
#
# $\langle Z\rangle=\cos(\theta)$
#
# Thus:
#
# $\frac{\sqrt{2}}{2}+\frac{\sqrt{2}}{2}=\sqrt{2}$
#
# </details>
#
# ---

# %% [markdown]
# ## Question 16
#
# Consider:
#
# ```python
# qc.h(0)
# qc.cx(0,1)
# qc.h(1)
# ```
#
# What state is produced?
#
# A. $\frac{|00\rangle+|01\rangle+|10\rangle-|11\rangle}{2}$
#
# B. $\frac{|00\rangle+|01\rangle-|10\rangle+|11\rangle}{2}$
#
# C. $|\Phi^+\rangle$
#
# D. $|\Psi^+\rangle$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 17
#
# Starting from:
#
# $|\Phi^+\rangle=\frac{|00\rangle+|11\rangle}{\sqrt{2}}$
#
# Apply $Z$ to qubit 0 and $Z$ to qubit 1.
#
# Which state is obtained?
#
# A. $|\Phi^+\rangle$
#
# B. $|\Phi^-\rangle$
#
# C. $|\Psi^+\rangle$
#
# D. $|\Psi^-\rangle$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 18
#
# Consider:
#
# ```python
# from qiskit.quantum_info import SparsePauliOp
#
# obs = SparsePauliOp(["XX", "ZZ"])
# ```
#
# and the Bell state
#
# $|\Phi^+\rangle=\frac{|00\rangle+|11\rangle}{\sqrt{2}}$
#
# What is:
#
# $\langle XX + ZZ \rangle$
#
# A. $-2$
#
# B. $0$
#
# C. $1$
#
# D. $2$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: D**
#
# For $|\Phi^+\rangle$:
#
# $\langle XX\rangle = 1$
#
# $\langle ZZ\rangle = 1$
#
# Therefore:
#
# $1 + 1 = 2$
#
# </details>
#
# ---

# %% [markdown]
# ## Question 19
#
# For
#
# $|\Phi^-\rangle=\frac{|00\rangle-|11\rangle}{\sqrt{2}}$
#
# what is:
#
# $\langle XX + YY - ZZ\rangle$
#
# A. $-3$
#
# B. $-1$
#
# C. $1$
#
# D. $3$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# For $|\Phi^-\rangle$:
#
# $\langle XX\rangle=-1$
#
# $\langle YY\rangle=1$
#
# $\langle ZZ\rangle=1$
#
# Therefore:
#
# $-1+1-1=-1$
#
# </details>
#
# ---

# %% [markdown]
# ## Question 20
#
# Consider:
#
# ```python
# qc.h(0)
# qc.cx(0,1)
# qc.h(0)
# qc.h(1)
# ```
#
# What is the resulting state?
#
# A. $|00\rangle$
#
# B. $\frac{|00\rangle+|01\rangle+|10\rangle+|11\rangle}{2}$
#
# C. $\frac{|00\rangle+|11\rangle}{\sqrt{2}}$
#
# D. $\frac{|00\rangle+|01\rangle+|10\rangle-|11\rangle}{2}$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
#
#
# </details>

# %% [markdown]
# ## Question 21
#
# Consider:
#
# ```python
# qc.h(0)
# qc.cx(0,1)
# qc.x(0)
# ```
#
# Which Bell state is produced?
#
# A. $|\Phi^+\rangle$
#
# B. $|\Phi^-\rangle$
#
# C. $|\Psi^+\rangle$
#
# D. $|\Psi^-\rangle$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# Starting from:
#
# $|\Phi^+\rangle$
#
# Applying $X$ to either qubit transforms:
#
# $|\Phi^+\rangle \rightarrow |\Psi^+\rangle$
#
# Applying $Z$ changes the sign of the bell state
#
# </details>
#
# ---

# %% [markdown]
# ## Question 22
#
# A qubit is prepared as:
#
# ```python
# qc.ry(np.pi/3, 0)
# ```
#
# What is the value of $\langle Z\rangle$?
#
# A. $\frac{1}{2}$
#
# B. $\frac{\sqrt{3}}{2}$
#
# C. $-\frac{1}{2}$
#
# D. $-\frac{\sqrt{3}}{2}$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# $\langle Z\rangle=\cos(\pi/3)=\frac{1}{2}$
#
# </details>
#
# ---

# %% [markdown]
# ## Question 24
#
# Starting from $|00\rangle$:
#
# ```python
# qc.x(0)
# qc.h(0)
# qc.cx(0,1)
# ```
#
# Which Bell state is produced?
#
# A. $|\Phi^+\rangle$
#
# B. $|\Phi^-\rangle$
#
# C. $|\Psi^+\rangle$
#
# D. $|\Psi^-\rangle$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# $X$ then $H$ creates:
#
# $\frac{|0\rangle-|1\rangle}{\sqrt{2}}$
#
# Entangling gives:
#
# $|\Phi^-\rangle$
#
# </details>
#
# ---

# %% [markdown]
# ## Question 25
#
# For
#
# $|\Phi^+\rangle=\frac{|00\rangle+|11\rangle}{\sqrt{2}}$
#
# what is $\langle YY\rangle$?
#
# A. $-1$
#
# B. $0$
#
# C. $1$
#
# D. $2$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: A**
#
# Applying $YY$ gives:
#
# $YY|\Phi^+\rangle=-|\Phi^+\rangle$
#
# Therefore:
#
# $\langle YY\rangle=-1$
#
# </details>
#
# ---

# %% [markdown]
# ## Question 26
#
# A qubit is prepared as:
#
# ```python
# qc.rx(np.pi/2, 0)
# ```
#
# What is the value of $\langle Z\rangle$?
#
# A. $-1$
#
# B. $0$
#
# C. $1$
#
# D. $\frac{\sqrt{2}}{2}$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# For:
#
# $R_x(\theta)|0\rangle$
#
# we have:
#
# $\langle Z\rangle=\cos(\theta)$
#
# Thus:
#
# $\cos(\pi/2)=0$
#
# </details>
#
# ---

# %% [markdown]
# ## Question 27
#
# Consider:
#
# ```python
# qc.h(0)
# qc.cx(0,1)
# qc.x(1)
# ```
#
# Which Bell state is produced?
#
# A. $|\Phi^+\rangle$
#
# B. $|\Phi^-\rangle$
#
# C. $|\Psi^+\rangle$
#
# D. $|\Psi^-\rangle$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: C**
#
# </details>
#
# ---

# %% [markdown]
# ## Question 28
#
# Consider:
#
# ```python
# qc.h(0)
# qc.cx(0,1)
# qc.z(0)
# qc.x(1)
# ```
#
# Which Bell state is produced?
#
# A. $|\Psi^+\rangle$
#
# B. $|\Psi^-\rangle$
#
# C. $|\Phi^+\rangle$
#
# D. $|\Phi^-\rangle$
#
# <details>
# <summary>Answer</summary>
#
# **Answer: B**
#
# </details>
#
# ---
